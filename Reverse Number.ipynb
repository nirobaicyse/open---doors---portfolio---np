# %% [markdown]
# <a href="https://colab.research.google.com/github/nirobaicyse/open---doors---portfolio---np/blob/main/Reverse%20Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 6 - Reverse Number
n = input().strip()
print(n[::-1])
# Out:
# 5.6
# 6.5
