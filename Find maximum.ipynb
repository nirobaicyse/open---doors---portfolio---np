# %% [markdown]
# <a href="https://colab.research.google.com/github/nirobaicyse/open---doors---portfolio---np/blob/main/Find%20maximum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 4 - Find Maximum
n = int(input())
nums = list(map(int, input().split()))
print(max(nums))
# Out:
# 5
# 6
# 6
