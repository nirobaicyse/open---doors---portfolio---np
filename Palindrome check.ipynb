# %% [markdown]
# <a href="https://colab.research.google.com/github/nirobaicyse/open---doors---portfolio---np/blob/main/Palindrome%20check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 6 - Palindrome Check
s = input().strip()
print("YES" if s == s[::-1] else "NO")
# Out:
# 5.6
# NO
