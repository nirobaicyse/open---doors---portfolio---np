# %% [markdown]
# <a href="https://colab.research.google.com/github/nirobaicyse/open---doors---portfolio---np/blob/main/vowel_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 6 - Count Vowels
text = input().lower()
count = sum(1 for c in text if c in "aeiou")
print(count)
# Out:
# bangladesh
# 3
