# %% [markdown]
# <a href="https://colab.research.google.com/github/nirobaicyse/open---doors---portfolio---np/blob/main/Fibpnacci%20series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 3 - Fibonacci Series
n = int(input())
a, b = 0, 1
series = []
for _ in range(n):
    series.append(str(a))
    a, b = b, a + b
print(" ".join(series))
# Out:
# 6
# 0 1 1 2 3 5
